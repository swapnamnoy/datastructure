# %% [raw]
# ### 1. **String Slicing in Python**
# String slicing allows you to access a subset of a string by specifying a range of indices.
#
# **Syntax**:
# `string[start:stop:step]`
#
# - `start`: The index to begin the slice (inclusive).
# - `stop`: The index to stop the slice (exclusive).
# - `step`: The interval between characters (default is 1).
#
# **Examples**:
# ```python
# text = "Hello, World!"
# print(text[0:5])    # Output: 'Hello'
# print(text[7:])     # Output: 'World!'
# print(text[::2])    # Output: 'Hlo ol!'
# print(text[::-1])   # Output: '!dlroW ,olleH' (reverses the string)
# ```
#
# ### 2. **Key Features of Lists in Python**
# - **Mutable**: Lists can be changed (elements can be added, removed, or modified).
# - **Ordered**: Elements have a defined order, and that order will not change unless explicitly modified.
# - **Indexable**: You can access elements using their index.
# - **Dynamic**: Lists can grow and shrink in size.
# - **Heterogeneous**: They can store different types of elements (integers, strings, other lists, etc.).
#
# **Example**:
# ```python
# my_list = [1, 'apple', 3.14, [5, 6]]
# ```
#
# ### 3. **Access, Modify, and Delete Elements in a List**
#
# **Accessing Elements**:
# You can access elements by index (0-based).
# ```python
# my_list = [10, 20, 30, 40]
# print(my_list[2])  # Output: 30
# ```
#
# **Modifying Elements**:
# You can change the value of an element at a specific index.
# ```python
# my_list[1] = 25
# print(my_list)  # Output: [10, 25, 30, 40]
# ```
#
# **Deleting Elements**:
# You can delete elements using `del`, `remove()`, or `pop()`.
# ```python
# del my_list[1]   # Deletes the element at index 1
# print(my_list)   # Output: [10, 30, 40]
#
# my_list.remove(30)   # Removes the first occurrence of value 30
# print(my_list)       # Output: [10, 40]
#
# my_list.pop(0)   # Removes and returns the element at index 0
# print(my_list)   # Output: [40]
# ```
#
# ### 4. **Comparison of Tuples and Lists**
#
# | Feature    | Lists                     | Tuples                    |
# |------------|----------------------------|----------------------------|
# | Mutability | Mutable (can be changed)    | Immutable (cannot be changed)|
# | Syntax     | Square brackets: `[]`       | Parentheses: `()`           |
# | Use Cases  | Dynamic collections         | Fixed collections (e.g., coordinates)|
# | Performance| Slower (due to mutability)  | Faster (due to immutability)|
# | Methods    | Many methods (append, pop)  | Fewer methods (count, index)|
#
# **Example**:
# ```python
# my_list = [1, 2, 3]  # Mutable
# my_tuple = (1, 2, 3) # Immutable
# ```
#
# ### 5. **Key Features of Sets in Python**
#
# - **Unordered**: Elements in a set are not stored in any particular order.
# - **Unindexed**: You cannot access set elements by index.
# - **No Duplicates**: Sets automatically remove duplicate items.
# - **Mutable**: You can add or remove elements, but the elements themselves must be immutable.
#
# **Example**:
# ```python
# my_set = {1, 2, 3, 4, 4}  # Duplicate '4' is removed
# print(my_set)  # Output: {1, 2, 3, 4}
# ```
#
# **Common Use Cases**:
# - **Membership Testing**: Check if an element is in a set.
# - **Set Operations**: Union, intersection, difference.
#
# ```python
# set1 = {1, 2, 3}
# set2 = {3, 4, 5}
# print(set1 & set2)  # Intersection: {3}
# print(set1 | set2)  # Union: {1, 2, 3, 4, 5}
# ```
#
# ### 6. **Use Cases of Tuples and Sets**
#
# - **Tuples**:
#   - Use tuples when you need an **immutable** and **ordered** collection.
#   - Example: Coordinates `(x, y)`, return multiple values from a function.
#
#   ```python
#   point = (5, 10)  # Fixed point in a 2D space
#   ```
#
# - **Sets**:
#   - Use sets when you need to store **unique** elements and perform **membership checks** or **set operations**.
#   - Example: Keep track of unique items, perform union and intersection of datasets.
#
#   ```python
#   seen_items = {1, 2, 3}
#   ```
#
# ### 7. **Adding, Modifying, and Deleting Items in a Dictionary**
#
# **Adding**:
# ```python
# my_dict = {'name': 'Alice', 'age': 25}
# my_dict['city'] = 'New York'  # Adding a new key-value pair
# print(my_dict)  # Output: {'name': 'Alice', 'age': 25, 'city': 'New York'}
# ```
#
# **Modifying**:
# ```python
# my_dict['age'] = 26  # Modify the value associated with a key
# print(my_dict)  # Output: {'name': 'Alice', 'age': 26, 'city': 'New York'}
# ```
#
# **Deleting**:
# ```python
# del my_dict['city']  # Deleting a key-value pair
# print(my_dict)  # Output: {'name': 'Alice', 'age': 26}
#
# my_dict.pop('age')  # Removes and returns the value for the key 'age'
# print(my_dict)  # Output: {'name': 'Alice'}
# ```
#
# ### 8. **Importance of Dictionary Keys Being Immutable**
#
# In Python, dictionary keys must be immutable types (such as strings, integers, or tuples) because the dictionary uses a **hashing** mechanism to quickly retrieve values. Immutable objects ensure that the hash value remains constant.
#
# If keys were mutable, changing a key would break the internal structure of the dictionary, leading to inconsistencies.
#
# **Example**:
# ```python
# # Valid key types
# my_dict = {(1, 2): 'coordinates', 'name': 'Alice', 42: 'Answer'}
#
# # Invalid key (list is mutable)
# # my_dict[[1, 2]] = 'invalid'  # Raises TypeError
# ```
#
# The immutability of keys ensures efficient and reliable lookups in dictionaries.
